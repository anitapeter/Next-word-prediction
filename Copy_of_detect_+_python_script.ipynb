# %% [markdown]
# <a href="https://colab.research.google.com/github/anitapeter/Next-word-prediction/blob/master/Copy_of_detect_%2B_python_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os.path import exists, join, basename, splitext

# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [819 B]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [87.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# ...

# %%
git_repo_url = 'https://github.com/anitapeter/project.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt

# %%
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
IMAGE_URL = 'https://i2.wp.com/media.boingboing.net/wp-content/uploads/2018/03/Cat-sofa-Paws-Purrs.jpg?ssl=1'

# %%
image_file = basename(IMAGE_URL)
# !wget -q -O $image_file $IMAGE_URL
plt.imshow(matplotlib.image.imread(image_file))

# %%
# !cp "/content/drive/My Drive/yolov3.weights" "project/yolov3.weights"

# %%
# !cp "/content/drive/My Drive/yolov3.weights" "yolov3.weights"

# %%
# !cd project && python detect.py --weights ../yolov3.weights --images ../$image_file --det ..
# Out:
# Loading network.....
# Network successfully loaded
# Cat-sofa-Paws-Purrs.jpg?ssl=1 predicted in  0.085 seconds
#
# ----------------------------------------------------------
#
# SUMMARY
# ----------------------------------------------------------
# Task                     : Time Taken (in seconds)
#
# Reading addresses        : 0.000
# Loading batch            : 0.411
# Detection (1 images)     : 0.099
# Output Processing        : 0.000
# Drawing Boxes            : 0.081
# Average time_per_img     : 0.591
# ----------------------------------------------------------

# %%
plt.figure(figsize=(20, 15))
plt.imshow(matplotlib.image.imread('det_%s' % image_file))

# %%
# !cd project && python generator.py
# Out:
#  #instagood #ig #cats #catsofinstagram #of #catstagram #instagram #catlover #instacat #catlovers #kitten #kitty #meow #pet #cute #love #dog #catoftheday #catlife #pets #gato #kittens #animals #world #cutecat #animal #catlove #gatos #adoptdontshop #chat #bhfyp #dogsofinstagram #dogs #puppy #dogstagram #instadog #doglover #love #pet #dogoftheday #cute #doglovers #instagram #pets #doglife #puppylove #of #doggo #puppies #puppiesofinstagram #cat #ilovemydog #dogsofinsta #hund #animals #doggy #petstagram #petsofinstagram #doglove #bhfyp #furniture #interiordesign #design #interior #table #homedecor #furnituredesign #home #sofa #chairs #decor #architecture #interiors #art #livingroom #decoration #wood #vintage #sandalye #office #armchair #furniture #interiordesign #design #interior #table #homedecor #furnituredesign #home #sofa #chairs #decor #architecture #interiors #art #livingroom #decoration #wood #vintage #sandalye #office #armchair #houseplants #flowers #kvety #kv #ty #rastliny #close
# ...
